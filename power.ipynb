# %%
import pandas as pd

data_dir = "C:\\Users\\alvar\\University of Southampton\\GDP - General\\Flight Day 2\\data\\batlead.csv"

data = pd.read_csv(data_dir)

data["Power"] = data["Curr"] * data["Volt"]

data.plot("timestamp", "Power")
# Out:
# <AxesSubplot: xlabel='timestamp'>
